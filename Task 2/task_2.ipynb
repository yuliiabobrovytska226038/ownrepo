# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
def find_petri_dish_thresholding(image):
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Apply adaptive thresholding
    _, thresh = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

    # Find contours in the thresholded image
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Filter contours based on area to find the Petri dish contour
    petri_dish_contour = None
    min_contour_area = 4000 

    for contour in contours:
        if cv2.contourArea(contour) > min_contour_area:
            petri_dish_contour = contour
            break

    # Extract bounding box coordinates of the Petri dish
    x, y, w, h = cv2.boundingRect(petri_dish_contour)

    # Ensure the bounding box is a square
    side_length = max(w, h)
    x_center, y_center = x + w // 2, y + h // 2

    # Crop the Petri dish from the original image
    petri_dish = image[y:y + h, x:x + w]

    # Resize the cropped Petri dish to 2770x2770
    petri_dish = cv2.resize(petri_dish, (2770, 2770))

    # Convert the cropped Petri dish to grayscale
    petri_dish_gray = cv2.cvtColor(petri_dish, cv2.COLOR_BGR2GRAY)

    return petri_dish_gray

# %%
# Test the code on 5 different images
image_1_path = r"C:\Users\User\Desktop\Block B\DataLab tasks\Task 2\Images\000_43-18-ROOT1-2023-08-08_pvdCherry_OD001_Col0_01-Fish Eye Corrected.png"
image_2_path = r"C:\Users\User\Desktop\Block B\DataLab tasks\Task 2\Images\001_43-6-ROOT1-2023-08-08_pvdCherry_OD001_Col0_04-Fish Eye Corrected.png"
image_3_path = r"C:\Users\User\Desktop\Block B\DataLab tasks\Task 2\Images\005_43-2-ROOT1-2023-08-08_control_pH7_-Fe+B_col0_04-Fish Eye Corrected.png"
image_4_path = r"C:\Users\User\Desktop\Block B\DataLab tasks\Task 2\Images\005_43-18-ROOT1-2023-08-08_pvd_OD001_Col0_05-Fish Eye Corrected.png"
image_5_path = r"C:\Users\User\Desktop\Block B\DataLab tasks\Task 2\Images\010_43-18-ROOT1-2023-08-08_pvd_OD001_f6h1_04-Fish Eye Corrected.png"

# %%
# Read the image
img_1 = cv2.imread(image_1_path)

# Find and extract the Petri dish using color-based segmentation
petri_dish_1 = find_petri_dish_thresholding(img_1)

# Display the original and cropped images side by side
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB))
plt.title("Original Image")

plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(petri_dish_1, cv2.COLOR_BGR2RGB))
plt.title("Cropped Petri Dish")

plt.show()

# %%
petri_dish_1.shape
# Out:
# (2770, 2770)

# %%
# Read the image
img_2 = cv2.imread(image_2_path)

# Find and extract the Petri dish using color-based segmentation
petri_dish_2 = find_petri_dish_thresholding(img_2)

# Display the original and cropped images side by side
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(img_2, cv2.COLOR_BGR2RGB))
plt.title("Original Image")

plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(petri_dish_2, cv2.COLOR_BGR2RGB))
plt.title("Cropped Petri Dish")

plt.show()

# %%
petri_dish_2.shape
# Out:
# (2770, 2770)

# %%
# Read the image
img_3 = cv2.imread(image_3_path)

# Find and extract the Petri dish using color-based segmentation
petri_dish_3 = find_petri_dish_thresholding(img_3)

# Display the original and cropped images side by side
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(img_3, cv2.COLOR_BGR2RGB))
plt.title("Original Image")

plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(petri_dish_3, cv2.COLOR_BGR2RGB))
plt.title("Cropped Petri Dish")

plt.show()

# %%
petri_dish_3.shape
# Out:
# (2770, 2770)

# %%
# Read the image
img_4 = cv2.imread(image_4_path)

# Find and extract the Petri dish using color-based segmentation
petri_dish_4 = find_petri_dish_thresholding(img_4)

# Display the original and cropped images side by side
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(img_4, cv2.COLOR_BGR2RGB))
plt.title("Original Image")

plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(petri_dish_4, cv2.COLOR_BGR2RGB))
plt.title("Cropped Petri Dish")

plt.show()

# %%
petri_dish_4.shape
# Out:
# (2770, 2770)

# %%
# Read the image
img_5 = cv2.imread(image_5_path)

# Find and extract the Petri dish using color-based segmentation
petri_dish_5 = find_petri_dish_thresholding(img_5)

# Display the original and cropped images side by side
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(img_5, cv2.COLOR_BGR2RGB))
plt.title("Original Image")

plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(petri_dish_5, cv2.COLOR_BGR2RGB))
plt.title("Cropped Petri Dish")

plt.show()

# %%
petri_dish_5.shape
# Out:
# (2770, 2770)
